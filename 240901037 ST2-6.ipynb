# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Generate data
dates = pd.date_range('2024-01-01', periods=365)
prices = 100 + np.cumsum(np.random.randn(365))
# Create DataFrame
df = pd.DataFrame({'Price': prices}, index=dates)
# Basic analysis
print("Avg:", df['Price'].mean())
print("Max:", df['Price'].max())
print("Min:", df['Price'].min())
# Moving average
df['MA'] = df['Price'].rolling(7).mean()
# Plot
df.plot()
plt.show()
# Out:
# Avg: 98.63219361102662
# Max: 122.57216879372481
# Min: 73.31665941190789
